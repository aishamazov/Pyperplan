# %% [markdown]
# # AI-Cognitive: алгоритм планирования STRIPS 2017

# %% [markdown]
# # Эксперимент на выявление эффективных алгоритмов (часть 3)

# %% [markdown]
# ## Используемые алгоритмы:
#
#
# ### 1) Алгоритм поиска ids (Iterative deepening search)
#
#
# ### 2) Алгоритм поиска bfs (breadth-first search)
#
#
# ### 3) Алгоритм поиска A* (A-star search) + эвристика hMax
#
#
# ### 4) Алгоритм поиска gbf (greedy best-first search) + эвристика hMax
#
#
# ### 5) Алгоритм поиска A* (A-star search) + эвристика hAdd

# %% [markdown]
# ### Рассмотрим задачи tpp из папки benchmark

# %%
import numpy as np

# %%
ids_min = []
bfs_min = []
hmax_astar_min = []
hmax_gbf_min = []
hadd_astar_min = []

# %%
ids_max = []
bfs_max = []
hmax_astar_max = []
hmax_gbf_max = []
hadd_astar_max = []

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -s ids pyperplan-master/benchmarks/tpp/task01.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
ids_min.append(mean - std)
ids_max.append(mean + std)
# Out:
# 2018-10-11 16:23:40,599 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:23:40,601 INFO     using search: iterative_deepening_search
# 2018-10-11 16:23:40,602 INFO     using heuristic: None
# 2018-10-11 16:23:40,602 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:23:40,607 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task01.pddl
# 2018-10-11 16:23:40,609 INFO     7 Predicates parsed
# 2018-10-11 16:23:40,609 INFO     4 Actions parsed
# 2018-10-11 16:23:40,610 INFO     6 Objects parsed
# 2018-10-11 16:23:40,611 INFO     0 Constants parsed
# 2018-10-11 16:23:40,611 INFO     Grounding start: tpp
# 2018-10-11 16:23:40,612 INFO     Relevance analysis removed 1 facts
# 2018-10-11 16:23:40,613 INFO     Grounding end: tpp
# 2018-10-11 16:23:40,614 INFO     10 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -s ids pyperplan-master/benchmarks/tpp/task02.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
ids_min.append(mean - std)
ids_max.append(mean + std)
# Out:
# 2018-10-11 16:23:43,845 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:23:43,846 INFO     using search: iterative_deepening_search
# 2018-10-11 16:23:43,847 INFO     using heuristic: None
# 2018-10-11 16:23:43,848 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:23:43,852 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task02.pddl
# 2018-10-11 16:23:43,854 INFO     7 Predicates parsed
# 2018-10-11 16:23:43,855 INFO     4 Actions parsed
# 2018-10-11 16:23:43,855 INFO     7 Objects parsed
# 2018-10-11 16:23:43,856 INFO     0 Constants parsed
# 2018-10-11 16:23:43,857 INFO     Grounding start: tpp
# 2018-10-11 16:23:43,858 INFO     Relevance analysis removed 2 facts
# 2018-10-11 16:23:43,859 INFO     Grounding end: tpp
# 2018-10-11 16:23:43,860 INFO     18 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -s ids pyperplan-master/benchmarks/tpp/task03.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
ids_min.append(mean - std)
ids_max.append(mean + std)
# Out:
# 2018-10-11 16:23:47,157 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:23:47,158 INFO     using search: iterative_deepening_search
# 2018-10-11 16:23:47,159 INFO     using heuristic: None
# 2018-10-11 16:23:47,160 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:23:47,165 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task03.pddl
# 2018-10-11 16:23:47,169 INFO     7 Predicates parsed
# 2018-10-11 16:23:47,170 INFO     4 Actions parsed
# 2018-10-11 16:23:47,171 INFO     8 Objects parsed
# 2018-10-11 16:23:47,171 INFO     0 Constants parsed
# 2018-10-11 16:23:47,172 INFO     Grounding start: tpp
# 2018-10-11 16:23:47,174 INFO     Relevance analysis removed 3 facts
# 2018-10-11 16:23:47,174 INFO     Grounding end: tpp
# 2018-10-11 16:23:47,175 INFO     26 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -s ids pyperplan-master/benchmarks/tpp/task04.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
ids_min.append(mean - std)
ids_max.append(mean + std)
# Out:
# 2018-10-11 16:23:53,577 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:23:53,577 INFO     using search: iterative_deepening_search
# 2018-10-11 16:23:53,578 INFO     using heuristic: None
# 2018-10-11 16:23:53,578 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:23:53,581 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task04.pddl
# 2018-10-11 16:23:53,585 INFO     7 Predicates parsed
# 2018-10-11 16:23:53,585 INFO     4 Actions parsed
# 2018-10-11 16:23:53,587 INFO     9 Objects parsed
# 2018-10-11 16:23:53,588 INFO     0 Constants parsed
# 2018-10-11 16:23:53,589 INFO     Grounding start: tpp
# 2018-10-11 16:23:53,590 INFO     Relevance analysis removed 4 facts
# 2018-10-11 16:23:53,591 INFO     Grounding end: tpp
# 2018-10-11 16:23:53,592 INFO     34 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -s bfs pyperplan-master/benchmarks/tpp/task01.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
bfs_min.append(mean - std)
bfs_max.append(mean + std)
# Out:
# 2018-10-11 16:24:21,495 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:21,496 INFO     using search: breadth_first_search
# 2018-10-11 16:24:21,497 INFO     using heuristic: None
# 2018-10-11 16:24:21,498 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:21,501 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task01.pddl
# 2018-10-11 16:24:21,502 INFO     7 Predicates parsed
# 2018-10-11 16:24:21,503 INFO     4 Actions parsed
# 2018-10-11 16:24:21,503 INFO     6 Objects parsed
# 2018-10-11 16:24:21,504 INFO     0 Constants parsed
# 2018-10-11 16:24:21,505 INFO     Grounding start: tpp
# 2018-10-11 16:24:21,506 INFO     Relevance analysis removed 1 facts
# 2018-10-11 16:24:21,506 INFO     Grounding end: tpp
# 2018-10-11 16:24:21,507 INFO     10 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -s bfs pyperplan-master/benchmarks/tpp/task02.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
bfs_min.append(mean - std)
bfs_max.append(mean + std)
# Out:
# 2018-10-11 16:24:24,664 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:24,665 INFO     using search: breadth_first_search
# 2018-10-11 16:24:24,666 INFO     using heuristic: None
# 2018-10-11 16:24:24,667 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:24,671 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task02.pddl
# 2018-10-11 16:24:24,673 INFO     7 Predicates parsed
# 2018-10-11 16:24:24,674 INFO     4 Actions parsed
# 2018-10-11 16:24:24,675 INFO     7 Objects parsed
# 2018-10-11 16:24:24,676 INFO     0 Constants parsed
# 2018-10-11 16:24:24,677 INFO     Grounding start: tpp
# 2018-10-11 16:24:24,679 INFO     Relevance analysis removed 2 facts
# 2018-10-11 16:24:24,680 INFO     Grounding end: tpp
# 2018-10-11 16:24:24,680 INFO     18 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -s bfs pyperplan-master/benchmarks/tpp/task03.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
bfs_min.append(mean - std)
bfs_max.append(mean + std)
# Out:
# 2018-10-11 16:24:27,454 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:27,454 INFO     using search: breadth_first_search
# 2018-10-11 16:24:27,455 INFO     using heuristic: None
# 2018-10-11 16:24:27,456 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:27,460 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task03.pddl
# 2018-10-11 16:24:27,462 INFO     7 Predicates parsed
# 2018-10-11 16:24:27,463 INFO     4 Actions parsed
# 2018-10-11 16:24:27,463 INFO     8 Objects parsed
# 2018-10-11 16:24:27,464 INFO     0 Constants parsed
# 2018-10-11 16:24:27,465 INFO     Grounding start: tpp
# 2018-10-11 16:24:27,466 INFO     Relevance analysis removed 3 facts
# 2018-10-11 16:24:27,467 INFO     Grounding end: tpp
# 2018-10-11 16:24:27,467 INFO     26 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -s bfs pyperplan-master/benchmarks/tpp/task04.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
bfs_min.append(mean - std)
bfs_max.append(mean + std)
# Out:
# 2018-10-11 16:24:30,230 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:30,231 INFO     using search: breadth_first_search
# 2018-10-11 16:24:30,231 INFO     using heuristic: None
# 2018-10-11 16:24:30,232 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:30,235 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task04.pddl
# 2018-10-11 16:24:30,237 INFO     7 Predicates parsed
# 2018-10-11 16:24:30,237 INFO     4 Actions parsed
# 2018-10-11 16:24:30,238 INFO     9 Objects parsed
# 2018-10-11 16:24:30,239 INFO     0 Constants parsed
# 2018-10-11 16:24:30,239 INFO     Grounding start: tpp
# 2018-10-11 16:24:30,241 INFO     Relevance analysis removed 4 facts
# 2018-10-11 16:24:30,242 INFO     Grounding end: tpp
# 2018-10-11 16:24:30,243 INFO     34 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -s bfs pyperplan-master/benchmarks/tpp/task05.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
bfs_min.append(mean - std)
bfs_max.append(mean + std)
# Out:
# 2018-10-11 16:24:33,376 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:33,377 INFO     using search: breadth_first_search
# 2018-10-11 16:24:33,378 INFO     using heuristic: None
# 2018-10-11 16:24:33,379 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:33,382 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task05.pddl
# 2018-10-11 16:24:33,384 INFO     7 Predicates parsed
# 2018-10-11 16:24:33,384 INFO     4 Actions parsed
# 2018-10-11 16:24:33,385 INFO     12 Objects parsed
# 2018-10-11 16:24:33,385 INFO     0 Constants parsed
# 2018-10-11 16:24:33,386 INFO     Grounding start: tpp
# 2018-10-11 16:24:33,389 INFO     Relevance analysis removed 10 facts
# 2018-10-11 16:24:33,391 INFO     Grounding end: tpp
# 2018-10-11 16:24:33,391 INFO     76 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hmax -s astar pyperplan-master/benchmarks/tpp/task01.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hmax_astar_min.append(mean - std)
hmax_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:24:41,076 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:41,077 INFO     using search: astar_search
# 2018-10-11 16:24:41,078 INFO     using heuristic: hMaxHeuristic
# 2018-10-11 16:24:41,078 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:41,081 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task01.pddl
# 2018-10-11 16:24:41,082 INFO     7 Predicates parsed
# 2018-10-11 16:24:41,083 INFO     4 Actions parsed
# 2018-10-11 16:24:41,084 INFO     6 Objects parsed
# 2018-10-11 16:24:41,085 INFO     0 Constants parsed
# 2018-10-11 16:24:41,086 INFO     Grounding start: tpp
# 2018-10-11 16:24:41,087 INFO     Relevance analysis removed 1 facts
# 2018-10-11 16:24:41,088 INFO     Grounding end: tpp
# 2018-10-11 16:24:41,089 INFO     10 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hmax -s astar pyperplan-master/benchmarks/tpp/task02.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hmax_astar_min.append(mean - std)
hmax_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:24:43,795 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:43,796 INFO     using search: astar_search
# 2018-10-11 16:24:43,796 INFO     using heuristic: hMaxHeuristic
# 2018-10-11 16:24:43,796 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:43,799 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task02.pddl
# 2018-10-11 16:24:43,802 INFO     7 Predicates parsed
# 2018-10-11 16:24:43,803 INFO     4 Actions parsed
# 2018-10-11 16:24:43,804 INFO     7 Objects parsed
# 2018-10-11 16:24:43,805 INFO     0 Constants parsed
# 2018-10-11 16:24:43,806 INFO     Grounding start: tpp
# 2018-10-11 16:24:43,807 INFO     Relevance analysis removed 2 facts
# 2018-10-11 16:24:43,807 INFO     Grounding end: tpp
# 2018-10-11 16:24:43,808 INFO     18 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hmax -s astar pyperplan-master/benchmarks/tpp/task03.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hmax_astar_min.append(mean - std)
hmax_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:24:46,644 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:46,645 INFO     using search: astar_search
# 2018-10-11 16:24:46,646 INFO     using heuristic: hMaxHeuristic
# 2018-10-11 16:24:46,647 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:46,651 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task03.pddl
# 2018-10-11 16:24:46,653 INFO     7 Predicates parsed
# 2018-10-11 16:24:46,653 INFO     4 Actions parsed
# 2018-10-11 16:24:46,654 INFO     8 Objects parsed
# 2018-10-11 16:24:46,654 INFO     0 Constants parsed
# 2018-10-11 16:24:46,655 INFO     Grounding start: tpp
# 2018-10-11 16:24:46,656 INFO     Relevance analysis removed 3 facts
# 2018-10-11 16:24:46,658 INFO     Grounding end: tpp
# 2018-10-11 16:24:46,659 INFO     26 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hmax -s astar pyperplan-master/benchmarks/tpp/task04.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hmax_astar_min.append(mean - std)
hmax_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:24:50,562 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:50,562 INFO     using search: astar_search
# 2018-10-11 16:24:50,563 INFO     using heuristic: hMaxHeuristic
# 2018-10-11 16:24:50,563 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:24:50,567 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task04.pddl
# 2018-10-11 16:24:50,569 INFO     7 Predicates parsed
# 2018-10-11 16:24:50,570 INFO     4 Actions parsed
# 2018-10-11 16:24:50,571 INFO     9 Objects parsed
# 2018-10-11 16:24:50,571 INFO     0 Constants parsed
# 2018-10-11 16:24:50,572 INFO     Grounding start: tpp
# 2018-10-11 16:24:50,573 INFO     Relevance analysis removed 4 facts
# 2018-10-11 16:24:50,574 INFO     Grounding end: tpp
# 2018-10-11 16:24:50,574 INFO     34 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hmax -s astar pyperplan-master/benchmarks/tpp/task05.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hmax_astar_min.append(mean - std)
hmax_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:25:00,831 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:25:00,832 INFO     using search: astar_search
# 2018-10-11 16:25:00,832 INFO     using heuristic: hMaxHeuristic
# 2018-10-11 16:25:00,833 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:25:00,836 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task05.pddl
# 2018-10-11 16:25:00,839 INFO     7 Predicates parsed
# 2018-10-11 16:25:00,840 INFO     4 Actions parsed
# 2018-10-11 16:25:00,840 INFO     12 Objects parsed
# 2018-10-11 16:25:00,841 INFO     0 Constants parsed
# 2018-10-11 16:25:00,841 INFO     Grounding start: tpp
# 2018-10-11 16:25:00,844 INFO     Relevance analysis removed 10 facts
# 2018-10-11 16:25:00,844 INFO     Grounding end: tpp
# 2018-10-11 16:25:00,845 INFO     76 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hmax -s gbf pyperplan-master/benchmarks/tpp/task01.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hmax_gbf_min.append(mean - std)
hmax_gbf_max.append(mean + std)
# Out:
# 2018-10-11 16:27:10,285 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:27:10,286 INFO     using search: greedy_best_first_search
# 2018-10-11 16:27:10,287 INFO     using heuristic: hMaxHeuristic
# 2018-10-11 16:27:10,288 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:27:10,291 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task01.pddl
# 2018-10-11 16:27:10,293 INFO     7 Predicates parsed
# 2018-10-11 16:27:10,293 INFO     4 Actions parsed
# 2018-10-11 16:27:10,294 INFO     6 Objects parsed
# 2018-10-11 16:27:10,294 INFO     0 Constants parsed
# 2018-10-11 16:27:10,295 INFO     Grounding start: tpp
# 2018-10-11 16:27:10,296 INFO     Relevance analysis removed 1 facts
# 2018-10-11 16:27:10,297 INFO     Grounding end: tpp
# 2018-10-11 16:27:10,297 INFO     10 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hmax -s gbf pyperplan-master/benchmarks/tpp/task02.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hmax_gbf_min.append(mean - std)
hmax_gbf_max.append(mean + std)
# Out:
# 2018-10-11 16:27:13,077 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:27:13,078 INFO     using search: greedy_best_first_search
# 2018-10-11 16:27:13,078 INFO     using heuristic: hMaxHeuristic
# 2018-10-11 16:27:13,079 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:27:13,082 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task02.pddl
# 2018-10-11 16:27:13,084 INFO     7 Predicates parsed
# 2018-10-11 16:27:13,085 INFO     4 Actions parsed
# 2018-10-11 16:27:13,086 INFO     7 Objects parsed
# 2018-10-11 16:27:13,086 INFO     0 Constants parsed
# 2018-10-11 16:27:13,087 INFO     Grounding start: tpp
# 2018-10-11 16:27:13,088 INFO     Relevance analysis removed 2 facts
# 2018-10-11 16:27:13,089 INFO     Grounding end: tpp
# 2018-10-11 16:27:13,089 INFO     18 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hmax -s gbf pyperplan-master/benchmarks/tpp/task03.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hmax_gbf_min.append(mean - std)
hmax_gbf_max.append(mean + std)
# Out:
# 2018-10-11 16:27:15,896 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:27:15,897 INFO     using search: greedy_best_first_search
# 2018-10-11 16:27:15,899 INFO     using heuristic: hMaxHeuristic
# 2018-10-11 16:27:15,900 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:27:15,903 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task03.pddl
# 2018-10-11 16:27:15,905 INFO     7 Predicates parsed
# 2018-10-11 16:27:15,906 INFO     4 Actions parsed
# 2018-10-11 16:27:15,906 INFO     8 Objects parsed
# 2018-10-11 16:27:15,907 INFO     0 Constants parsed
# 2018-10-11 16:27:15,909 INFO     Grounding start: tpp
# 2018-10-11 16:27:15,910 INFO     Relevance analysis removed 3 facts
# 2018-10-11 16:27:15,912 INFO     Grounding end: tpp
# 2018-10-11 16:27:15,912 INFO     26 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hmax -s gbf pyperplan-master/benchmarks/tpp/task04.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hmax_gbf_min.append(mean - std)
hmax_gbf_max.append(mean + std)
# Out:
# 2018-10-11 16:27:18,977 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:27:18,978 INFO     using search: greedy_best_first_search
# 2018-10-11 16:27:18,978 INFO     using heuristic: hMaxHeuristic
# 2018-10-11 16:27:18,979 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:27:18,983 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task04.pddl
# 2018-10-11 16:27:18,985 INFO     7 Predicates parsed
# 2018-10-11 16:27:18,985 INFO     4 Actions parsed
# 2018-10-11 16:27:18,986 INFO     9 Objects parsed
# 2018-10-11 16:27:18,986 INFO     0 Constants parsed
# 2018-10-11 16:27:18,987 INFO     Grounding start: tpp
# 2018-10-11 16:27:18,988 INFO     Relevance analysis removed 4 facts
# 2018-10-11 16:27:18,989 INFO     Grounding end: tpp
# 2018-10-11 16:27:18,989 INFO     34 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hmax -s gbf pyperplan-master/benchmarks/tpp/task05.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hmax_gbf_min.append(mean - std)
hmax_gbf_max.append(mean + std)
# Out:
# 2018-10-11 16:27:23,790 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:27:23,791 INFO     using search: greedy_best_first_search
# 2018-10-11 16:27:23,792 INFO     using heuristic: hMaxHeuristic
# 2018-10-11 16:27:23,793 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:27:23,797 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task05.pddl
# 2018-10-11 16:27:23,799 INFO     7 Predicates parsed
# 2018-10-11 16:27:23,800 INFO     4 Actions parsed
# 2018-10-11 16:27:23,801 INFO     12 Objects parsed
# 2018-10-11 16:27:23,801 INFO     0 Constants parsed
# 2018-10-11 16:27:23,802 INFO     Grounding start: tpp
# 2018-10-11 16:27:23,805 INFO     Relevance analysis removed 10 facts
# 2018-10-11 16:27:23,807 INFO     Grounding end: tpp
# 2018-10-11 16:27:23,807 INFO     76 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hadd -s astar pyperplan-master/benchmarks/tpp/task01.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hadd_astar_min.append(mean - std)
hadd_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:28:08,081 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:08,082 INFO     using search: astar_search
# 2018-10-11 16:28:08,082 INFO     using heuristic: hAddHeuristic
# 2018-10-11 16:28:08,083 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:08,086 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task01.pddl
# 2018-10-11 16:28:08,088 INFO     7 Predicates parsed
# 2018-10-11 16:28:08,089 INFO     4 Actions parsed
# 2018-10-11 16:28:08,089 INFO     6 Objects parsed
# 2018-10-11 16:28:08,090 INFO     0 Constants parsed
# 2018-10-11 16:28:08,090 INFO     Grounding start: tpp
# 2018-10-11 16:28:08,091 INFO     Relevance analysis removed 1 facts
# 2018-10-11 16:28:08,092 INFO     Grounding end: tpp
# 2018-10-11 16:28:08,093 INFO     10 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hadd -s astar pyperplan-master/benchmarks/tpp/task02.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hadd_astar_min.append(mean - std)
hadd_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:28:10,806 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:10,807 INFO     using search: astar_search
# 2018-10-11 16:28:10,807 INFO     using heuristic: hAddHeuristic
# 2018-10-11 16:28:10,808 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:10,811 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task02.pddl
# 2018-10-11 16:28:10,813 INFO     7 Predicates parsed
# 2018-10-11 16:28:10,813 INFO     4 Actions parsed
# 2018-10-11 16:28:10,814 INFO     7 Objects parsed
# 2018-10-11 16:28:10,815 INFO     0 Constants parsed
# 2018-10-11 16:28:10,816 INFO     Grounding start: tpp
# 2018-10-11 16:28:10,817 INFO     Relevance analysis removed 2 facts
# 2018-10-11 16:28:10,818 INFO     Grounding end: tpp
# 2018-10-11 16:28:10,819 INFO     18 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hadd -s astar pyperplan-master/benchmarks/tpp/task03.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hadd_astar_min.append(mean - std)
hadd_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:28:13,647 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:13,648 INFO     using search: astar_search
# 2018-10-11 16:28:13,648 INFO     using heuristic: hAddHeuristic
# 2018-10-11 16:28:13,649 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:13,652 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task03.pddl
# 2018-10-11 16:28:13,654 INFO     7 Predicates parsed
# 2018-10-11 16:28:13,654 INFO     4 Actions parsed
# 2018-10-11 16:28:13,655 INFO     8 Objects parsed
# 2018-10-11 16:28:13,655 INFO     0 Constants parsed
# 2018-10-11 16:28:13,656 INFO     Grounding start: tpp
# 2018-10-11 16:28:13,657 INFO     Relevance analysis removed 3 facts
# 2018-10-11 16:28:13,657 INFO     Grounding end: tpp
# 2018-10-11 16:28:13,658 INFO     26 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hadd -s astar pyperplan-master/benchmarks/tpp/task04.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hadd_astar_min.append(mean - std)
hadd_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:28:17,083 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:17,083 INFO     using search: astar_search
# 2018-10-11 16:28:17,084 INFO     using heuristic: hAddHeuristic
# 2018-10-11 16:28:17,085 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:17,088 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task04.pddl
# 2018-10-11 16:28:17,091 INFO     7 Predicates parsed
# 2018-10-11 16:28:17,091 INFO     4 Actions parsed
# 2018-10-11 16:28:17,092 INFO     9 Objects parsed
# 2018-10-11 16:28:17,092 INFO     0 Constants parsed
# 2018-10-11 16:28:17,093 INFO     Grounding start: tpp
# 2018-10-11 16:28:17,095 INFO     Relevance analysis removed 4 facts
# 2018-10-11 16:28:17,095 INFO     Grounding end: tpp
# 2018-10-11 16:28:17,096 INFO     34 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hadd -s astar pyperplan-master/benchmarks/tpp/task05.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hadd_astar_min.append(mean - std)
hadd_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:28:20,993 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:20,994 INFO     using search: astar_search
# 2018-10-11 16:28:20,994 INFO     using heuristic: hAddHeuristic
# 2018-10-11 16:28:20,995 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:20,998 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task05.pddl
# 2018-10-11 16:28:21,001 INFO     7 Predicates parsed
# 2018-10-11 16:28:21,002 INFO     4 Actions parsed
# 2018-10-11 16:28:21,002 INFO     12 Objects parsed
# 2018-10-11 16:28:21,003 INFO     0 Constants parsed
# 2018-10-11 16:28:21,003 INFO     Grounding start: tpp
# 2018-10-11 16:28:21,006 INFO     Relevance analysis removed 10 facts
# 2018-10-11 16:28:21,007 INFO     Grounding end: tpp
# 2018-10-11 16:28:21,008 INFO     76 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hadd -s astar pyperplan-master/benchmarks/tpp/task06.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hadd_astar_min.append(mean - std)
hadd_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:28:25,656 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:25,657 INFO     using search: astar_search
# 2018-10-11 16:28:25,657 INFO     using heuristic: hAddHeuristic
# 2018-10-11 16:28:25,658 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:25,661 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task06.pddl
# 2018-10-11 16:28:25,664 INFO     7 Predicates parsed
# 2018-10-11 16:28:25,665 INFO     4 Actions parsed
# 2018-10-11 16:28:25,665 INFO     14 Objects parsed
# 2018-10-11 16:28:25,666 INFO     0 Constants parsed
# 2018-10-11 16:28:25,666 INFO     Grounding start: tpp
# 2018-10-11 16:28:25,678 INFO     Relevance analysis removed 17 facts
# 2018-10-11 16:28:25,679 INFO     Grounding end: tpp
# 2018-10-11 16:28:25,680 INFO     132 Variables created
# ...

# %%
result = %%timeit -o %run ./pyperplan-master/src/pyperplan.py -H hadd -s astar pyperplan-master/benchmarks/tpp/task07.pddl
mean = np.array(result.all_runs).mean()/result.loops
std = np.array(result.all_runs).std()/result.loops
hadd_astar_min.append(mean - std)
hadd_astar_max.append(mean + std)
# Out:
# 2018-10-11 16:28:29,070 INFO     Found domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:29,071 INFO     using search: astar_search
# 2018-10-11 16:28:29,071 INFO     using heuristic: hAddHeuristic
# 2018-10-11 16:28:29,072 INFO     Parsing Domain C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\domain.pddl
# 2018-10-11 16:28:29,076 INFO     Parsing Problem C:\Users\Arthur\Anaconda3\Scripts\pyperplan-master\benchmarks\tpp\task07.pddl
# 2018-10-11 16:28:29,080 INFO     7 Predicates parsed
# 2018-10-11 16:28:29,081 INFO     4 Actions parsed
# 2018-10-11 16:28:29,081 INFO     15 Objects parsed
# 2018-10-11 16:28:29,082 INFO     0 Constants parsed
# 2018-10-11 16:28:29,082 INFO     Grounding start: tpp
# 2018-10-11 16:28:29,100 INFO     Relevance analysis removed 18 facts
# 2018-10-11 16:28:29,101 INFO     Grounding end: tpp
# 2018-10-11 16:28:29,102 INFO     153 Variables created
# ...

# %%
print('ids_min: ', ids_min)
print('ids_max: ', ids_max, '\n')
print('bfs_min: ', bfs_min)
print('bfs_max: ', bfs_max, '\n')
print('hmax_astar_min: ', hmax_astar_min)
print('hmax_astar_max: ', hmax_astar_max, '\n')
print('hmax_gbf_min: ', hmax_gbf_min)
print('hmax_gbf_max: ', hmax_gbf_max, '\n')
print('hadd_astar_min: ', hadd_astar_min)
print('hadd_astar_max: ', hadd_astar_max, '\n')
# Out:
# ids_min:  [0.038373177249075095, 0.03800670781362209, 0.07336085005762512, 3.1809864152779883]
# ids_max:  [0.041261643637741825, 0.042133266083908494, 0.0858220693462456, 3.7835668734414205]
#
# bfs_min:  [0.036033156032938565, 0.032423220914406053, 0.033097478397268947, 0.03775214651680908, 0.8509628917068512]
# bfs_max:  [0.043518010306202726, 0.03345468461341805, 0.03484517295345992, 0.039587683982564084, 1.076713200862416]
#
# hmax_astar_min:  [0.032901075323920136, 0.03417079140843436, 0.045031847328675635, 0.12126497569438087, 15.707533107736236]
# hmax_astar_max:  [0.033540294393282565, 0.03562473429696798, 0.051313412144478314, 0.13156928312689029, 16.598873751237033]
#
# hmax_gbf_min:  [0.03283806179648677, 0.033377082945389366, 0.03693786103974754, 0.055430897243971586, 5.228265824711691]
# hmax_gbf_max:  [0.03360823673797335, 0.035699128693535975, 0.03852075158613251, 0.06534967852418781, 5.700138368076207]
#
# ...

# %% [markdown]
# ### Так как разница во времени между первыми и последними задачами велика, отмасшатибруем и потом прологарифмируем.

# %%
ids_min_scale = []
bfs_min_scale = []
hmax_astar_min_scale = []
hmax_gbf_min_scale = []
hadd_astar_min_scale = []

# %%
ids_max_scale = []
bfs_max_scale = []
hmax_astar_max_scale = []
hmax_gbf_max_scale = []
hadd_astar_max_scale = []

# %%
scale = 100
for num in ids_min:
    ids_min_scale.append(num*scale)
    
for num in bfs_min:
    bfs_min_scale.append(num*scale)

for num in hmax_astar_min:
    hmax_astar_min_scale.append(num*scale)

for num in hmax_gbf_min:
    hmax_gbf_min_scale.append(num*scale)

for num in hadd_astar_min:
    hadd_astar_min_scale.append(num*scale)

# %%
scale = 100
for num in ids_max:
    ids_max_scale.append(num*scale)
    
for num in bfs_max:
    bfs_max_scale.append(num*scale)

for num in hmax_astar_max:
    hmax_astar_max_scale.append(num*scale)

for num in hmax_gbf_max:
    hmax_gbf_max_scale.append(num*scale)

for num in hadd_astar_max:
    hadd_astar_max_scale.append(num*scale)

# %%
max_len = max(len(ids_min), len(bfs_min), len(hmax_astar_min), len(hmax_gbf_min), len(hadd_astar_min))
print(max_len)
# Out:
# 7

# %%
for i in range(max_len - len(ids_min)):
    ids_min_scale.append(1.)

for i in range(max_len - len(bfs_min)):
    bfs_min_scale.append(1.)

for i in range(max_len - len(hmax_astar_min)):
    hmax_astar_min_scale.append(1.)

for i in range(max_len - len(hmax_gbf_min)):
    hmax_gbf_min_scale.append(1.)

for i in range(max_len - len(hadd_astar_min)):
    hadd_astar_min_scale.append(1.)

# %%
for i in range(max_len - len(ids_max)):
    ids_max_scale.append(1.)

for i in range(max_len - len(bfs_max)):
    bfs_max_scale.append(1.)

for i in range(max_len - len(hmax_astar_max)):
    hmax_astar_max_scale.append(1.)

for i in range(max_len - len(hmax_gbf_max)):
    hmax_gbf_max_scale.append(1.)

for i in range(max_len - len(hadd_astar_max)):
    hadd_astar_max_scale.append(1.)

# %%
log_ids_min_scale = np.log(ids_min_scale)

log_bfs_min_scale = np.log(bfs_min_scale)

log_hmax_astar_min_scale = np.log(hmax_astar_min_scale)

log_hmax_gbf_min_scale = np.log(hmax_gbf_min_scale)

log_hadd_astar_min_scale = np.log(hadd_astar_min_scale)

# %%
log_ids_max_scale = np.log(ids_max_scale)

log_bfs_max_scale = np.log(bfs_max_scale)

log_hmax_astar_max_scale = np.log(hmax_astar_max_scale)

log_hmax_gbf_max_scale = np.log(hmax_gbf_max_scale)

log_hadd_astar_max_scale = np.log(hadd_astar_max_scale)

# %%
print('ids_min: ', ids_min)
print('ids_max: ', ids_max, '\n')
print('ids_min_scale: ', ids_min_scale)
print('ids_max_scale: ', ids_max_scale, '\n')
print('log_ids_min_scale: ', log_ids_min_scale)
print('log_ids_max_scale: ', log_ids_max_scale, '\n')
# Out:
# ids_min:  [0.038373177249075095, 0.03800670781362209, 0.07336085005762512, 3.1809864152779883]
# ids_max:  [0.041261643637741825, 0.042133266083908494, 0.0858220693462456, 3.7835668734414205]
#
# ids_min_scale:  [3.8373177249075097, 3.800670781362209, 7.336085005762512, 318.0986415277988, 1.0, 1.0, 1.0]
# ids_max_scale:  [4.1261643637741825, 4.213326608390849, 8.58220693462456, 378.3566873441421, 1.0, 1.0, 1.0]
#
# log_ids_min_scale:  [1.34477361 1.33517757 1.99280532 5.76236153 0.         0.
#  0.        ]
# log_ids_max_scale:  [1.41734825 1.4382525  2.1496911  5.93583737 0.         0.
#  0.        ]

# %%
print('bfs_min: ', bfs_min)
print('bfs_max: ', bfs_max, '\n')
print('bfs_min_scale: ', bfs_min_scale)
print('bfs_max_scale: ', bfs_max_scale, '\n')
print('log_bfs_min_scale: ', log_bfs_min_scale)
print('log_bfs_max_scale: ', log_bfs_max_scale, '\n')
# Out:
# bfs_min:  [0.036033156032938565, 0.032423220914406053, 0.033097478397268947, 0.03775214651680908, 0.8509628917068512]
# bfs_max:  [0.043518010306202726, 0.03345468461341805, 0.03484517295345992, 0.039587683982564084, 1.076713200862416]
#
# bfs_min_scale:  [3.6033156032938565, 3.2423220914406055, 3.3097478397268945, 3.7752146516809084, 85.09628917068513, 1.0, 1.0]
# bfs_max_scale:  [4.351801030620273, 3.345468461341805, 3.4845172953459924, 3.9587683982564084, 107.67132008624161, 1.0, 1.0]
#
# log_bfs_min_scale:  [1.28185442 1.17628977 1.19687201 1.32845724 4.44378343 0.
#  0.        ]
# log_bfs_max_scale:  [1.47058979 1.20760673 1.24832953 1.37593297 4.67908325 0.
#  0.        ]

# %%
print('hmax_astar_min: ', hmax_astar_min)
print('hmax_astar_max: ', hmax_astar_max, '\n')
print('hmax_astar_min_scale: ', hmax_astar_min_scale)
print('hmax_astar_max_scale: ', hmax_astar_max_scale, '\n')
print('log_hmax_astar_min_scale: ', log_hmax_astar_min_scale)
print('log_hmax_astar_max_scale: ', log_hmax_astar_max_scale, '\n')
# Out:
# hmax_astar_min:  [0.032901075323920136, 0.03417079140843436, 0.045031847328675635, 0.12126497569438087, 15.707533107736236]
# hmax_astar_max:  [0.033540294393282565, 0.03562473429696798, 0.051313412144478314, 0.13156928312689029, 16.598873751237033]
#
# hmax_astar_min_scale:  [3.2901075323920135, 3.4170791408434362, 4.503184732867563, 12.126497569438087, 1570.7533107736235, 1.0, 1.0]
# hmax_astar_max_scale:  [3.3540294393282566, 3.5624734296967984, 5.131341214447831, 13.156928312689029, 1659.8873751237034, 1.0, 1.0]
#
# log_hmax_astar_min_scale:  [1.19092025 1.22878613 1.50478486 2.49539294 7.3593106  0.
#  0.        ]
# log_hmax_astar_max_scale:  [1.21016244 1.27045509 1.63536707 2.57694849 7.41450503 0.
#  0.        ]

# %%
print('hmax_gbf_min: ', hmax_gbf_min)
print('hmax_gbf_max: ', hmax_gbf_max, '\n')
print('hmax_gbf_min_scale: ', hmax_gbf_min_scale)
print('hmax_gbf_max_scale: ', hmax_gbf_max_scale, '\n')
print('log_hmax_gbf_min_scale: ', log_hmax_gbf_min_scale)
print('log_hmax_gbf_max_scale: ', log_hmax_gbf_max_scale, '\n')
# Out:
# hmax_gbf_min:  [0.03283806179648677, 0.033377082945389366, 0.03693786103974754, 0.055430897243971586, 5.228265824711691]
# hmax_gbf_max:  [0.03360823673797335, 0.035699128693535975, 0.03852075158613251, 0.06534967852418781, 5.700138368076207]
#
# hmax_gbf_min_scale:  [3.2838061796486766, 3.3377082945389365, 3.693786103974754, 5.543089724397158, 522.8265824711691, 1.0, 1.0]
# hmax_gbf_max_scale:  [3.3608236737973347, 3.5699128693535975, 3.852075158613251, 6.534967852418781, 570.0138368076207, 1.0, 1.0]
#
# log_hmax_gbf_min_scale:  [1.18900317 1.20528443 1.30665198 1.71255206 6.25924983 0.
#  0.        ]
# log_hmax_gbf_max_scale:  [1.21218608 1.27254119 1.34861201 1.87716743 6.34566064 0.
#  0.        ]

# %%
print('hadd_astar_min: ', hadd_astar_min)
print('hadd_astar_max: ', hadd_astar_max, '\n')
print('hadd_astar_min_scale: ', hadd_astar_min_scale)
print('hadd_astar_max_scale: ', hadd_astar_max_scale, '\n')
print('log_hadd_astar_min_scale: ', log_hadd_astar_min_scale)
print('log_hadd_astar_max_scale: ', log_hadd_astar_max_scale, '\n')
# Out:
# hadd_astar_min:  [0.032586379362201, 0.03376341992267728, 0.03795547178351288, 0.0463236790879153, 0.05646113877586784, 0.3778933795805307, 9.767196664633879]
# hadd_astar_max:  [0.03409273529367327, 0.03579820690059248, 0.04813563723366133, 0.04913267891428825, 0.05818295804352503, 0.48251174551029674, 10.818758495874992]
#
# hadd_astar_min_scale:  [3.2586379362201, 3.3763419922677276, 3.7955471783512875, 4.63236790879153, 5.646113877586784, 37.78933795805307, 976.7196664633879]
# hadd_astar_max_scale:  [3.409273529367327, 3.579820690059248, 4.813563723366133, 4.913267891428825, 5.818295804352503, 48.25117455102968, 1081.8758495874993]
#
# log_hadd_astar_min_scale:  [1.1813093  1.21679287 1.33382858 1.53306816 1.7309675  3.632027
#  6.88419968]
# log_hadd_astar_max_scale:  [1.22649923 1.27531271 1.57143771 1.59193928 1.7610074  3.87642017
#  6.98645171]

# %% [markdown]
# ### Теперь извлекаем макимальную затраченную память на соответствующую задачу

# %%
mem_ids = [31.660156, 33.082031, 33.175781, 33.214844, 0., 0., 0.]
mem_bfs = [31.746094, 33.175781, 31.824219, 31.859375, 85.574219, 0., 0.]
mem_hmax_astar = [33.000000, 32.035156, 33.070312, 33.460938, 76.480469, 0., 0.]
mem_hmax_gbf = [33.042969, 33.054688, 33.074219, 33.121094, 53.156250, 0., 0.]
mem_hadd_astar = [31.894531, 33.117188, 32.152344, 33.476562, 33.312500, 35.449219, 65.746094]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
import csv

data_names = ['task01','task02','task03', 'task04', 'task05','task06','task07']

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('log_time_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))

plt.bar([x  for x in xs], log_ids_max_scale,
        width = 0.3, color = 'black', alpha = 0.7, zorder = 2)

plt.bar([x  for x in xs], log_ids_min_scale,
        width = 0.3, color = 'red', label = 'ids', zorder = 2)


plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 11., 0.5), fontsize = 15)
plt.ylabel('Scaled log time', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('mem_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))

plt.bar([x  for x in xs], mem_ids,
        width = 0.3, color = 'red', alpha = 0.7, label = 'ids', zorder = 2)


plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 40., 2.), fontsize = 15)
plt.ylabel('Memory (MiB)', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('log_time_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))


plt.bar([x for x in xs], log_bfs_max_scale,
        width = 0.3, color = 'black', alpha = 0.7, zorder = 2)

plt.bar([x for x in xs], log_bfs_min_scale,
        width = 0.3, color = 'orange', label = 'bfs', zorder = 2)



plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 11., 0.5), fontsize = 15)
plt.ylabel('Scaled log time', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('mem_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))



plt.bar([x for x in xs], mem_bfs,
        width = 0.3, color = 'orange', alpha = 0.7, label = 'bfs', zorder = 2)



plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 90., 5.), fontsize = 15)
plt.ylabel('Memory (MiB)', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('log_time_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))


plt.bar([x  for x in xs], log_hmax_astar_max_scale,
        width = 0.3, color = 'black', alpha = 0.7, zorder = 2)

plt.bar([x  for x in xs], log_hmax_astar_min_scale,
        width = 0.3, color = 'yellow', label = 'hmax_astar', zorder = 2)

plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 8.5, 0.5), fontsize = 15)
plt.ylabel('Scaled log time', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('mem_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))


plt.bar([x  for x in xs], mem_hmax_astar,
        width = 0.3, color = 'yellow', alpha = 0.7, label = 'hmax_astar', zorder = 2)

plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 90., 5.), fontsize = 15)
plt.ylabel('Memory (MiB)', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('log_time_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))


plt.bar([x  for x in xs], log_hmax_gbf_max_scale,
        width = 0.3, color = 'black', alpha = 0.7, zorder = 2)

plt.bar([x  for x in xs], log_hmax_gbf_min_scale,
        width = 0.3, color = 'green', label = 'hmax_gbf', zorder = 2)

plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 8., 0.5), fontsize = 15)
plt.ylabel('Scaled log time', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('mem_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))



plt.bar([x  for x in xs], mem_hmax_gbf,
        width = 0.3, color = 'green', alpha = 0.7, label = 'hmax_gbf', zorder = 2)

plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 65., 5.), fontsize = 15)
plt.ylabel('Memory (MiB)', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('log_time_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))


plt.bar([x  for x in xs], log_hadd_astar_max_scale,
        width = 0.3, color = 'black', alpha = 0.7, zorder = 2)

plt.bar([x  for x in xs], log_hadd_astar_min_scale,
        width = 0.3, color = 'blue', label = 'hadd_astar', zorder = 2)

plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 8., 0.5), fontsize = 15)
plt.ylabel('Scaled log time', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('mem_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))


plt.bar([x  for x in xs], mem_hadd_astar,
        width = 0.3, color = 'blue', alpha = 0.7, label = 'hadd_astar', zorder = 2)

plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 80., 5.), fontsize = 15)
plt.ylabel('Memory (MiB)', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('log_time_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))

plt.bar([x - 0.3 for x in xs], log_ids_max_scale,
        width = 0.1, color = 'black', alpha = 0.7, zorder = 2)

plt.bar([x - 0.3 for x in xs], log_ids_min_scale,
        width = 0.1, color = 'red',  label = 'ids', zorder = 2)


plt.bar([x - 0.15 for x in xs], log_bfs_max_scale,
        width = 0.1, color = 'black', alpha = 0.7, zorder = 2)

plt.bar([x - 0.15 for x in xs], log_bfs_min_scale,
        width = 0.1, color = 'orange', label = 'bfs', zorder = 2)


plt.bar([x  for x in xs], log_hmax_astar_max_scale,
        width = 0.1, color = 'black', alpha = 0.7, zorder = 2)

plt.bar([x  for x in xs], log_hmax_astar_min_scale,
        width = 0.1, color = 'yellow', label = 'hmax_astar', zorder = 2)


plt.bar([x + 0.15 for x in xs], log_hmax_gbf_max_scale,
        width = 0.1, color = 'black', alpha = 0.7, zorder = 2)

plt.bar([x + 0.15 for x in xs], log_hmax_gbf_min_scale,
        width = 0.1, color = 'green', label = 'hmax_gbf', zorder = 2)


plt.bar([x + 0.3 for x in xs], log_hadd_astar_max_scale,
        width = 0.1, color = 'black', alpha = 0.7, zorder = 2)

plt.bar([x + 0.3 for x in xs], log_hadd_astar_min_scale,
        width = 0.1, color = 'blue', label = 'hadd_astar', zorder = 2)

plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 9., 0.5), fontsize = 15)
plt.ylabel('Scaled log time', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %% [markdown]
# ### Если мы хотим найти план минимально возможной длины, то из рассматриваемых алгоритмов самый быстрый на рассмотренных benchmark-тестах - bfs

# %% [markdown]
# ### Если мы хотим найти план не обязательно минимально возможной длины, то из рассматриваемых алгоритмов самый быстрый на рассмотренных benchmark-тестах - hadd_astar

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (512*3 / dpi, 384*3 / dpi) )

plt.title('mem_tpp', fontsize = 25)

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(data_names))

plt.bar([x - 0.3 for x in xs], mem_ids,
        width = 0.1, color = 'red', alpha = 0.7, label = 'ids', zorder = 2)

plt.bar([x - 0.15 for x in xs], mem_bfs,
        width = 0.1, color = 'orange', alpha = 0.7, label = 'bfs', zorder = 2)

plt.bar([x  for x in xs], mem_hmax_astar,
        width = 0.1, color = 'yellow', alpha = 0.7, label = 'hmax_astar', zorder = 2)

plt.bar([x + 0.15 for x in xs], mem_hmax_gbf,
        width = 0.1, color = 'green', alpha = 0.7, label = 'hmax_gbf', zorder = 2)

plt.bar([x + 0.3 for x in xs], mem_hadd_astar,
        width = 0.1, color = 'blue', alpha = 0.7, label = 'hadd_astar', zorder = 2)

plt.xticks(xs, data_names, fontsize = 20)
plt.yticks(np.arange(0., 95., 5.), fontsize = 15)
plt.ylabel('Memory (MiB)', fontsize = 'xx-large')

plt.legend(loc='upper left', fontsize =  'xx-large')

# %% [markdown]
# ### Если мы хотим найти план минимально возможной длины, то из рассматриваемых алгоритмов самый выгодный по памяти на рассмотренных benchmark-тестах - hmax_gbf

# %% [markdown]
# ### Если мы хотим найти план не обязательно минимально возможной длины, то из рассматриваемых алгоритмов самый выгодный по памяти на рассмотренных benchmark-тестах - hadd_astar
